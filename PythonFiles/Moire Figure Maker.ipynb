# %%
import numpy as np
import matplotlib.pyplot as plt
import math 
from IPython.display import display, Image
import latticegen
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
##### Making G - G


def tBLG(theta1, scale, res): 
    #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda

    a1 = 0.2464*scale  #graphene lattice constant
    r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector

    kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
    psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
    xi=0.

    lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
    lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
    lattice3 = latticegen.hexlattice_gen(r_k1, theta2+xi, res)             #Graphene
    
    data = (lattice1 + lattice2 + lattice3).compute()
    return(data)

# %%
##### Making hBN - G


def BNG(theta1, scale, res): 

    a1 = 0.2464*scale  #graphene lattice constant
    a2 = 0.2504*scale  #hBN lattice constant

    r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
    r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
    
    kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
    psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
    xi=0.

    lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
    lattice2 = latticegen.hexlattice_gen(r_k2, theta1+xi, res)             #hBN
    
    data = (lattice1 + lattice2).compute()
    return(data)

# %%
##### Making G - G - G


def tTLG(theta1, theta2, scale, res): 
    #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution

    a1 = 0.2464*scale  #graphene lattice constant
    r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector

    kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
    psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
    xi=0.

    lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
    lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
    lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, res)             #Graphene
    
    data = (lattice1 + lattice2 + lattice3).compute()
    return(data)

# %%
##### Making BN - G - BN


def BNGBN(theta1, theta2, scale, res): 
    #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda

    a1 = 0.2464*scale  #graphene lattice constant
    
    r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector

    kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
    psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
    xi=0.

    lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
    lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
    lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, res)             #Graphene
    
    data = (lattice1 + lattice2 + lattice3).compute()
    return(data)

# %% [markdown]
# ##### Save some pics
#
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1).T)/0.001)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')

# %% [markdown]
# #### Example
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
# import matplotlib.pyplot as plt, random
#
# def series(dots, colr):
#     a,b=[],[]
#     for i in range(dots):
#         a.append(random.randint(1,100))
#         b.append(random.randint(1,100))
#     plt.scatter(a,b, c=colr)
#     return()
# interact(series, dots=(1,100,1), colr=["red","orange","brown"]);

# %%
##### Making G - G - G


def tTLG(theta1, theta2, scale, res): 
    #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda

    a1 = 0.2464*scale  #graphene lattice constant

    r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector

    kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
    psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
    xi=0.

    lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
    lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
    lattice3 = latticegen.hexlattice_gen(r_k1, theta2+xi, res)             #Graphene
    
    data = (lattice1 + lattice2 + lattice3).compute()
    return(data)

# %%
def showtTLG(theta1, theta2, scale, res):
    fig, ax = plt.subplots(figsize=[10,10])

    im= ax.imshow((tTLG(theta1,theta2, scale, res).T))

ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
    
interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='theta1', max=5.0, min=-5.0, step=0.01), FloatSlider(…
# <function __main__.showtTLG(theta1, theta2, scale, res)>

# %%
# %history
# Out:
# fig, ax = plt.subplots(figsize=[10,10])
#
# BNGBN(1,11)
# plt.savefig('rewq.png')
# import numpy as np
# import matplotlib.pyplot as plt
# import math
# from IPython.display import display, Image
# import latticegen
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     im = ax.imshow(data.T,
#                    vmax=np.quantile(data,0.95),
#                    vmin=np.quantile(data,0.05),
#                    )
#
#     ax.set_xlabel('x (nm)')
#     ax.set_ylabel('y (nm)')
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# BNGBN(1,11)
# plt.savefig('rewq.png')
# plt.subplots(figsize=[10,10])
#
# BNGBN(1,11)
# plt.savefig('rewq.png')
# #plt.subplots(figsize=[10,10])
#
# BNGBN(1,11)
# plt.savefig('rewq.png')
# #plt.subplots(figsize=[10,10])
#
# BNGBN(1,11)
# plt.savefig('rew4321q.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('/GIFs/BNGBN/'+name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('/GIFs/BNGBN/'+name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig/BNGBN/'+name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('/BNGBN/'+name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig(name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('/BNGBN'+name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('/BNGBN/'+name+'.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('/BNGBN/QQQQ.png')
# name = '4321'
# BNGBN(1,11)
# plt.savefig('BNGBN/QQQQ.png')
# angle1 = 1
# angle2 = 2
#
# name = '4321'
#
# BNGBN(angle1,angle2)
#
# plt.savefig('BNGBN/QQQQ.png')
# import matplotlib.pyplot as plt
# import numpy as np
#
# from matplotlib.widgets import Button, Slider
#
#
# # The parametrized function to be plotted
# def f(t, amplitude, frequency):
#     return amplitude * np.sin(2 * np.pi * frequency * t)
#
# t = np.linspace(0, 1, 1000)
#
# # Define initial parameters
# init_amplitude = 5
# init_frequency = 3
#
# # Create the figure and the line that we will manipulate
# fig, ax = plt.subplots()
# line, = ax.plot(t, f(t, init_amplitude, init_frequency), lw=2)
# ax.set_xlabel('Time [s]')
#
# # adjust the main plot to make room for the sliders
# fig.subplots_adjust(left=0.25, bottom=0.25)
#
# # Make a horizontal slider to control the frequency.
# axfreq = fig.add_axes([0.25, 0.1, 0.65, 0.03])
# freq_slider = Slider(
#     ax=axfreq,
#     label='Frequency [Hz]',
#     valmin=0.1,
#     valmax=30,
#     valinit=init_frequency,
# )
#
# # Make a vertically oriented slider to control the amplitude
# axamp = fig.add_axes([0.1, 0.25, 0.0225, 0.63])
# amp_slider = Slider(
#     ax=axamp,
#     label="Amplitude",
#     valmin=0,
#     valmax=10,
#     valinit=init_amplitude,
#     orientation="vertical"
# )
#
#
# # The function to be called anytime a slider's value changes
# def update(val):
#     line.set_ydata(f(t, amp_slider.val, freq_slider.val))
#     fig.canvas.draw_idle()
#
#
# # register the update function with each slider
# freq_slider.on_changed(update)
# amp_slider.on_changed(update)
#
# # Create a `matplotlib.widgets.Button` to reset the sliders to initial values.
# resetax = fig.add_axes([0.8, 0.025, 0.1, 0.04])
# button = Button(resetax, 'Reset', hovercolor='0.975')
#
#
# def reset(event):
#     freq_slider.reset()
#     amp_slider.reset()
# button.on_clicked(reset)
#
# plt.show()
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
# import matplotlib.pyplot as plt, random
#
# def series(dots, colr):
#     a,b=[],[]
#     for i in range(dots):
#         a.append(random.randint(1,100))
#         b.append(random.randint(1,100))
#     plt.scatter(a,b, c=colr)
#     return()
# interact(series, dots=(1,100,1), colr=["red","orange","brown"]);
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
# import matplotlib.pyplot as plt, random
#
# def series(dots, colr):
#     for i in range(dots):
#         BNGBN(dots,1)
#     return()
# interact(series, dots=(1,100,1), colr=["red","orange","brown"]);
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
# import matplotlib.pyplot as plt, random
#
# def series(dots, colr):
#     for i in range(dots):
#         BNGBN(dots,1)
#     return()
# interact(series, dots=(1,10,1), colr=["red","orange","brown"]);
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# imshow(data.T)
# ax.imshow(data.T)
# data
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# data
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# imshow(BNGBN(1,1))
# ax.imshow(BNGBN(1,1))
# BNGBN(1,1)
# BNGBN(1,1)
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ax.imshow(BNGBN(1,1))
# BNGBN(1,1)
# ax.imshow(BNGBN(1,1))
# ax.imshow(BNGBN(1,1))
# im = ax.imshow(data.T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ax.imshow(BNGBN(1,1))
# im = ax.imshow(BNGBN(1,1).T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ax.imshow(BNGBN(1,1))
# im = ax.imshow(BNGBN(1,1).T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# im = ax.imshow(BNGBN(1,1).T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# p = BNGBN(1,1)
# im = ax.imshow(p.T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# im = ax.imshow(p.T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# im = ax.imshow(p.T)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# im = ax.imshow(p)
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
#     im = ax.imshow(data.T,
#                    vmax=np.quantile(data,0.95),
#                    vmin=np.quantile(data,0.05),
#                    )
#
#     ax.set_xlabel('x (nm)')
#     ax.set_ylabel('y (nm)')
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
#     im = ax.imshow(data.T,
#                    vmax=np.quantile(data,0.95),
#                    vmin=np.quantile(data,0.05),
#                    )
#
#     ax.set_xlabel('x (nm)')
#     ax.set_ylabel('y (nm)')
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     im = ax.imshow(data.T,
#                    vmax=np.quantile(data,0.95),
#                    vmin=np.quantile(data,0.05),
#                    )
#
#     ax.set_xlabel('x (nm)')
#     ax.set_ylabel('y (nm)')
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# BNGBN(1,1)
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     im = ax.imshow(data.T,
#                    vmax=np.quantile(data,0.95),
#                    vmin=np.quantile(data,0.05),
#                    )
#
#     ax.set_xlabel('x (nm)')
#     ax.set_ylabel('y (nm)')
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
#     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     im = ax.imshow(data.T,
#                    vmax=np.quantile(data,0.95),
#                    vmin=np.quantile(data,0.05),
#                    )
#
#     ax.set_xlabel('x (nm)')
#     ax.set_ylabel('y (nm)')
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# BNGBN(1,1)
# data
# BNGBN(1,1)
# print(data)
# ##### Making BN - G - BN
# a1 = 0.2464  #graphene lattice constant
# a2 = 0.2504  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# BNGBN(1,1)
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(data.T)
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN.T)
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(1,1).T)
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(1,1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(1,1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
# a2 = 0.2504*scale  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(3,-1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
# a2 = 0.2504*scale  #hBN lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
# r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
# def BNGBN(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k2, xi, 1)                   #hBN
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta3+xi, 1,            #hBN
#                                          kappa=kappa, psi=psi)
#
#
# #     fig, ax = plt.subplots(figsize=[10,10])
#
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# #     im = ax.imshow(data.T,
# #                    vmax=np.quantile(data,0.95),
# #                    vmin=np.quantile(data,0.05),
# #                    )
#
# #     ax.set_xlabel('x (nm)')
# #     ax.set_ylabel('y (nm)')
# #     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# ##### Making BN - G - BN
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tBLG(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 1)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# ##### Making G - G
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tBLG(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 1)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# ##### Making G - G - G
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tBLG(theta1, theta2):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 1)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# ##### Making G - G
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tBLG(theta1):
#     theta3=theta1+theta2 #angle between 1 and 3
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 1)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#
#     data = (lattice1 + lattice2).compute()
#     return(data)
# ##### Making G - G - G
# scale = 1    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tTLG(theta1, theta2): #theta1 angle between top and middle, theta angle between middle and bottom
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 1)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, 1)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# fig, ax = plt.subplots(figsize=[10,10])
#
#
# theta1
#
# im = ax.imshow(BNGBN(3,-1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(3,-1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(1,-1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(BNGBN(3,-1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# im = ax.imshow(tTLG(3,-1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = 1.56
#
# im = ax.imshow(tTLG(theta1,-theta1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# #ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = 1.56
#
# im = ax.imshow(tTLG(theta1,-theta1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ, \\kappa = {kappa:.3f}, \\psi = {psi:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = 1.56
#
# im = ax.imshow(tTLG(theta1,-theta1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = 1.56
#
# im = ax.imshow(tTLG(theta1,-theta1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = -1.56
#
# im = ax.imshow(tTLG(theta1,theta2).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# ##### Making G - G - G
# scale = 10    #1= true scale
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tTLG(theta1, theta2): #theta1 angle between top and middle, theta angle between middle and bottom
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 1)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 1)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, 1)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = -1.56
#
# im = ax.imshow(tTLG(theta1,theta2).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# ##### Making G - G - G
# scale = 10    #1= true scale
#
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tTLG(theta1, theta2): #theta1 angle between top and middle, theta angle between middle and bottom
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 2)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 2)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, 2)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# ##### Making G - G - G
# scale = 10    #1= true scale
#
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tTLG(theta1, theta2): #theta1 angle between top and middle, theta angle between middle and bottom
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 2)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 2)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, 2)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = -1.56
#
# im = ax.imshow(tTLG(theta1,theta2).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# ##### Making G - G - G
# scale = 100    #1= true scale
#
# a1 = 0.2464*scale  #graphene lattice constant
#
# r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
# def tTLG(theta1, theta2): #theta1 angle between top and middle, theta angle between middle and bottom
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, 2)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, 2)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, 2)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = -1.56
#
# im = ax.imshow(tTLG(theta1,theta2).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = -1.56
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data.T)
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.56
# theta2 = -1.56
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
#
# savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = {scale:.2f}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale:.2f}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale:f}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow(tTLG(theta1,theta2, 100, 1).T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1))/100.T)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1).T)/100)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1).T)/1000)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1).T)/10000)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1).T)/0.001)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# (tTLG(theta1,theta2, 100, 1).T)
# (tTLG(theta1,theta2, 100, 1).T)/100
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=45.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# fig, ax = plt.subplots(figsize=[10,10])
#
# theta1 = 1.1
# theta2 = -1.1
#
# im = ax.imshow((tTLG(theta1,theta2, 100, 1).T)/0.001)
#
# ax.set_xlabel('x (nm)')
# ax.set_ylabel('y (nm)')
# ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# plt.savefig('tTLG.png')
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
# ...
#
# #plt.imshow(tTLG(1,1,1,1))
# %history
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, -theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data.T)
# def showtTLG(theta1, theta2, scale, res, colr):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((colr(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'{colr} \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1), colr=['tTLG', BNGBN])
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((colr(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'{tTLG} \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'{tTLG} \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#     a2 = 0.2504*scale  #hBN lattice constant
#
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#     r_k2=latticegen.transformations.a_0_to_r_k(a2, symmetry=6)
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k2, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k2, theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
#
# fig, ax = plt.subplots(figsize=[10,10])
#
# def showtTLG(theta1, theta2, scale, res):
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#     ax.set_title(f'$\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1));
#
# #plt.imshow(tTLG(1,1,1,1))
# def showBNGBN(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((BNGBN(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'hBN-Graphene-hBN \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
#
# interact(showBNGBN, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1));
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
#
# fig, ax = plt.subplots(figsize=[10,10])
#
# def showtTLG(theta1, theta2, scale, res):
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#     ax.set_title(f'$\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1));
#
# #plt.imshow(tTLG(1,1,1,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# import numpy as np
# import matplotlib.pyplot as plt
# import math
# from IPython.display import display, Image
# import latticegen
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     #ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     #ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     #ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     #fig, ax = plt.subplots(figsize=[10,10])
#
#     #ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     #ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     #ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     #ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# ig, ax = plt.subplots(figsize=[10,10])
#
#
# def showtTLG(theta1, theta2, scale, res):
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# fig, ax = plt.subplots(figsize=[10,10])
#
#
# def showtTLG(theta1, theta2, scale, res):
#
#     ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# fig, ax = plt.subplots(figsize=[10,10])
#
#
# def showtTLG(theta1, theta2, scale, res):
#
#     fig = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# fig, ax = plt.subplots(figsize=[10,10])
#
#
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     fig = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     fig = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     fig = ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# ##### Making G - G - G
#
#
# def tTLG(theta1, theta2, scale, res):
#     #theta1 angle between top and middle, theta angle between middle and bottom, scale is zoom, res is resolution-kinda
#
#     a1 = 0.2464*scale  #graphene lattice constant
#
#     r_k1=latticegen.transformations.a_0_to_r_k(a1, symmetry=6)  #reciprocal lattice vector
#
#     kappa=1     #(float, default: 1) – strain/deformation magnitude. 1 corresponds to no strain.
#     psi=0.      #(float, default: 0) – Principal strain direction with respect to horizontal.
#     xi=0.
#
#     lattice1 = latticegen.hexlattice_gen(r_k1, xi, res)                   #Graphene
#     lattice2 = latticegen.hexlattice_gen(r_k1, theta1+xi, res)             #Graphene
#     lattice3 = latticegen.hexlattice_gen(r_k1, theta2+xi, res)             #Graphene
#
#     data = (lattice1 + lattice2 + lattice3).compute()
#     return(data)
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im= ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
#     ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# def showtTLG(theta1, theta2, scale, res):
#     fig, ax = plt.subplots(figsize=[10,10])
#
#     im= ax.imshow((tTLG(theta1,theta2, scale, res).T))
#
# ax.set_title(f'TWISTEDTRILAYER \n $\\theta_1 = {theta1:.2f}^\\circ, \\theta_2 = {theta2:.2f}^\\circ$, Scale = x{scale}');
#
# interact(showtTLG, theta1=(-5,5,0.01), theta2=(-5,5,0.01), scale=(1,100,1), res=(1,3,1))
# %history

# %%
pip install aquirdturtle_collapsible_headings
# Out:
# Requirement already satisfied: aquirdturtle_collapsible_headings in c:\users\user\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: jupyterlab==3.*,>=3.0.0rc13 in c:\users\user\anaconda3\lib\site-packages (from aquirdturtle_collapsible_headings) (3.6.3)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (8.15.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (23.1)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (6.3.2)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (5.3.0)
# Requirement already satisfied: jupyterlab-server~=2.19 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.22.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.23.4)
# Requirement already satisfied: jupyter-ydoc~=0.2.3 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.4)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.8.0)
# Requirement already satisfied: nbclassic in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.5.5)
# Requirement already satisfied: notebook<7 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (6.5.4)
# Requirement already satisfied: jinja2>=2.1 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.1->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.1.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (21.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (7.4.9)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (5.9.2)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.14.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (23.2.0)
# Requirement already satisfied: Send2Trash in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.17.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (5.7.1)
# Requirement already satisfied: websocket-client in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.58.0)
# Requirement already satisfied: pywinpty in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.0.10)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (305.1)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.9.0)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.8.2)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-ydoc~=0.2.3->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.5.9)
# Requirement already satisfied: babel>=2.10 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.9.6)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (4.17.3)
# Requirement already satisfied: requests>=2.28 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.31.0)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\lib\site-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\user\anaconda3\lib\site-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (6.25.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from nbclassic->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.2)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.4.6)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\user\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.8.2)
# Requirement already satisfied: jupyter-events>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.6.3)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (4.12.2)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2024.2.2)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in c:\users\user\anaconda3\lib\site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in c:\users\user\anaconda3\lib\site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.18.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.6.7)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (5.9.0)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.2.2)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from websocket-client->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.16.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.4)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.21)
# Requirement already satisfied: fqdn in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (2.1)
# Requirement already satisfied: uri-template in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->aquirdturtle_collapsible_headings) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
